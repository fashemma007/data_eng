# %% [markdown]
# ### PROJECT: Data Modeling with Postgres
# ##### Introduction
# ###### A startup called Sparkify wants to analyze the data they've been collecting on songs and user activity on their new music streaming app. The analytics team is particularly interested in understanding what songs users are listening to. Currently, they don't have an easy way to query their data, which resides in a directory of JSON logs on user activity on the app, as well as a directory with JSON metadata on the songs in their app.
#
# ###### They'd like a data engineer to create a Postgres database with tables designed to optimize queries on song play analysis, and bring you on the project. Your role is to create a database schema and ETL pipeline for this analysis. You'll be able to test your database and ETL pipeline by running queries given to you by the analytics team from Sparkify and compare your results with their expected results.
#
# ##### Project Description
# ` In this project, you'll apply what you've learned on data modeling with Postgres and build an ETL pipeline using Python. To complete the project, you will need to define fact and dimension tables for a star schema for a particular analytic focus, and write an ETL pipeline that transfers data from files in two local directories into these tables in Postgres using Python and SQL.`

# %% [markdown]
# ### -- Wrangling Theatre --

# %%
import pandas as pd
# !pip3 install glob2
import glob, os, json
log_sample = pd.read_json('C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11/2018-11-02-events.json', lines=True)

# %%
log_sample.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0  N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 1                       None  Logged In   Stefany      F              0
# 2        Death Cab for Cutie  Logged In   Stefany      F              1
# 3           Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                    Skillet  Logged In     Kevin      M              0
#
#    lastName     length level                  location method      page  \
# 0       Fox  288.99220  free  New Orleans-Metairie, LA    PUT  NextSong
# 1     White        NaN  free               Lubbock, TX    GET      Home
# 2     White  216.42404  free               Lubbock, TX    PUT  NextSong
# 3     White  221.33506  free               Lubbock, TX    PUT  NextSong
# 4  Arellano  178.02404  free   Harrisburg-Carlisle, PA    PUT  NextSong
#
#     registration  sessionId                             song  status  \
# ...

# %%
log_sample2 = pd.read_json('C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11/2018-11-02-events.json', lines=True)

log_sample2.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0  N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 1                       None  Logged In   Stefany      F              0
# 2        Death Cab for Cutie  Logged In   Stefany      F              1
# 3           Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                    Skillet  Logged In     Kevin      M              0
#
#    lastName     length level                  location method      page  \
# 0       Fox  288.99220  free  New Orleans-Metairie, LA    PUT  NextSong
# 1     White        NaN  free               Lubbock, TX    GET      Home
# 2     White  216.42404  free               Lubbock, TX    PUT  NextSong
# 3     White  221.33506  free               Lubbock, TX    PUT  NextSong
# 4  Arellano  178.02404  free   Harrisburg-Carlisle, PA    PUT  NextSong
#
#     registration  sessionId                             song  status  \
# ...

# %%
pwd
# Out:
# 'C:\\Users\\HP SPECTRE\\Downloads\\Udacity DE Course\\Relational Data Models'

# %% [markdown]
# ## Merge all json datasets

# %%
filedir = ("C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11")

json_pattern = os.path.join(filedir, '*.json')
file_list = glob.glob(json_pattern)

dfs = []
for file in file_list:
    print (file)
#     with open(file) as f:
#         json_data = pd.json_normalize(json.loads(f.read()))
#         json_data['site'] = file.rsplit("/", 1)[-1]
#     dfs.append(json_data)
# df = pd.concat(dfs)



# extension = 'json'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# #combine all files in the list
# combined_json = pd.concat([pd.read_json(f) for f in all_filenames ])

# #export to csv
# combined_json.to_json( "combined_json.json", index=False, encoding='utf-8-sig')
# Out:
# C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11\2018-11-01-events.json
# C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11\2018-11-02-events.json
# C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11\2018-11-03-events.json
# C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11\2018-11-04-events.json
# C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11\2018-11-05-events.json
# C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11\2018-11-06-events.json
# ...

# %%
filedir = ("C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//log_data//2018//11")

json_pattern = os.path.join(filedir, '*.json')
file_list = glob.glob(json_pattern)

dfs = []
for file in file_list:
    with open(file) as f:
#         sx = pd.read_json(file, lines=True)
#         print(sx.columns)
        json_data = pd.json_normalize(json.loads(f.read()))
        json_data['site'] = file.rsplit("/", 1)[-1]
    dfs.append(json_data)
df = pd.concat(dfs)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-54-2f54f67948a2> in <module>
#       9 #         sx = pd.read_json(file, lines=True)
#      10 #         print(sx.columns)
# ---> 11         json_data = pd.json_normalize(json.loads(f.read()))
#      12         json_data['site'] = file.rsplit("/", 1)[-1]
#      13     dfs.append(json_data)
#
# ~\Anaconda33\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda33\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
# ...

# %%
df.describe()
# Out:
#        itemInSession      length  registration   sessionId  status  \
# count      15.000000   11.000000  1.500000e+01   15.000000    15.0
# mean        2.600000  244.047339  1.540558e+12  127.000000   200.0
# std         2.772312   90.252182  3.253735e+08   45.639895     0.0
# min         0.000000  144.038730  1.540266e+12    9.000000   200.0
# 25%         0.000000  188.956280  1.540345e+12  139.000000   200.0
# 50%         2.000000  233.717100  1.540345e+12  139.000000   200.0
# 75%         4.500000  245.837915  1.540968e+12  139.000000   200.0
# max         8.000000  440.267300  1.541034e+12  169.000000   200.0
#
#                  ts      userId
# count  1.500000e+01   15.000000
# mean   1.541108e+12   20.000000
# std    1.542550e+06   24.532777
# min    1.541106e+12    8.000000
# 25%    1.541106e+12    8.000000
# 50%    1.541107e+12    8.000000
# 75%    1.541109e+12   26.000000
# max    1.541111e+12  101.000000

# %%
song_sample = pd.read_json('C://Users//HP SPECTRE//Downloads//Udacity DE Course//Relational Data Models//Project-1-Template//data//song_data//A//A//B//TRAABCL128F4286650.json', lines=True)

# %%
song_sample
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARC43071187B990240              NaN               NaN
#
#   artist_location   artist_name             song_id                     title  \
# 0      Wisner, LA  Wayne Watson  SOKEJEJ12A8C13E0D0  The Urgency (LP Version)
#
#     duration  year
# 0  245.21098     0
